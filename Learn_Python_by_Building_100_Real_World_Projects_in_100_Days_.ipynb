# %% [markdown]
# <a href="https://colab.research.google.com/github/jshikanga/PLP-Python-Assignment/blob/main/Learn_Python_by_Building_100_Real_World_Projects_in_100_Days_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
name = "Vivian"
age = 15
height = 5.8
is_gamer = True
print("name:", name)
print("age", age)
print("hieght", height)
print(is_gamer)
# Out:
# name: Vivian
# age 15
# hieght 5.8
# True

# %%
username = input("What is your name?")
print("Welcome, " + username + "!")
# Out:
# What is your name?Vivian
# Welcome, Vivian!

# %%
x = 3
y = 10
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# 13
# -7
# 30
# 0.3

# %% [markdown]
# **Decision Time: If, Elif, Else**

# %%
age = int(input("your age: "))
if age >= 18:
  print("you are an adult")
elif age >= 13:
  print("you are a teenager")
else:
  print("you are a minor")
# Out:
# your age: 15
# you are a teenager

# %% [markdown]
# **Loops Repeating Actions**

# %% [markdown]
# The While Loop, where you want to go over something over and over again until a particular scenerio is met

# %%
count = 0
while count < 10:
  print("count is:", count)
  count += 1
# Out:
# count is: 0
# count is: 1
# count is: 2
# count is: 3
# count is: 4
# count is: 5
# count is: 6
# count is: 7
# count is: 8
# count is: 9

# %%
video_games = ["Game 1", "Game 2", "Game 3"]
for game in video_games:
  print(game)
# Out:
# Game 1
# Game 2
# Game 3

# %% [markdown]
# **Lists : Keep Track of Stuff**

# %%
video_games = ["Game 1", "Game 2", "Game 3"]
print(video_games[0])

video_games.append("Game 4")
print(video_games)

video_games [1] = "Game 8"
print(video_games)
# Out:
# Game 1
# ['Game 1', 'Game 2', 'Game 3', 'Game 4']
# ['Game 1', 'Game 8', 'Game 3', 'Game 4']

# %% [markdown]
# **Functions : Build your own Commands**

# %%
def say_hello(person_name):
  print("Hello, " + person_name + " from your very first function")

say_hello("clyde")

def multiply (a,b):
  return a * b
result = multiply(3,5)
print("Result: ", result)
# Out:
# Hello, clyde from your very first function
# Result:  15

# %% [markdown]
# **Mini Project : Number Guessing Game**

# %%
# This is a library that python provides which has some functionalities or functions that creates random numbers
import random
secret_number = random.randint(1,10)
attempts = 3

print("I'm thinking of a number between 1 and 10")

while attempts > 0:
  guess = int(input("Take a Guess: "))
  if guess == secret_number:
    print("Congratulations! You guessed the number correctly!")
    break
  elif guess < secret_number:
    print("Your guess is too low.")
  else:
    print("Your guess is too high.")
  attempts -= 1
  if attempts > 0:
    print(f"You have {attempts} attempts left.")
  else:
    print(f"Sorry, you ran out of attempts. The secret number was {secret_number}.")
# Out:
# I'm thinking of a number between 1 and 10
# Take a Guess: 8
# Your guess is too high.
# You have 2 attempts left.
# Take a Guess: 7
# Your guess is too high.
# You have 1 attempts left.
# Take a Guess: 5
# Congratulations! You guessed the number correctly!
